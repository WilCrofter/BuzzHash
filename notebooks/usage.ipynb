# %% [markdown]
# # Usage
#
# This example of `BuzzHash` usage requires packages [`MNIST`](https://github.com/johnmyleswhite/MNIST.jl), [`GR`](https://github.com/jheinen/GR.jl), and [`Plots`](https://github.com/JuliaPlots/Plots.jl). It was originally implemented in `Julia 0.6.0` and is in process of upgrading to `Julia 1.9.2`. It uses the [MNIST handwritten digits](http://yann.lecun.com/exdb/mnist/) which are included in the [MLDatasets](https://docs.juliahub.com/MLDatasets/9CUQK/0.5.3/datasets/MNIST/) package.

# %%
using MLDatasets.MNIST
using Plots
gr() # use the GR back end for plots
include("../src/BuzzHash.jl")

# %% [markdown]
# The `MNIST` data consists of 60,000 training images with associated labels, `0, ..., 9`, and 10,000 test images with associated labels. These can be accessed with functions `trainfeatures(i)`, `trainlabel(i)`, `testfeatures(i)`, and `testlabel(i)` from the `MNIST` package. Below we pick 4 training images at random and determine their labels.

# %%
srand(1234); # set the RNG seed to 1234
indices = rand(1:60000,4);
for i in indices println(i,"\t",trainlabel(i)) end
# Out:
# 8429	2.0
# 35352	7.0
# 18860	9.0
# 14356	2.0

# %% [markdown]
# To display the associated images we use function `heatmap` from the `Plots` package (because it's easy.) Function `trainfeatures(i)` returns a 784 long vector which we reshape to a 28x28 matrix. Note that the reshaped indices must be adjusted to make the digits appear in their proper orientation. The necessary adjustments will vary with the `Plots` back end (e.g., `pyplot()` vs `gr()`,) and whether a notebook or REPL is used. I have no idea why.

# %%
x1 = trainfeatures(indices[1])
x2 = trainfeatures(indices[2])
x3 = trainfeatures(indices[3])
x4 = trainfeatures(indices[4])

plot(
    heatmap(reshape(x1,28,28)[:,28:-1:1],flip=true,color=:blues, title="2"),
    heatmap(reshape(x2,28,28)[:,28:-1:1],flip=true,color=:blues, title="7"),
    heatmap(reshape(x3,28,28)[:,28:-1:1],flip=true,color=:blues, title="9"),
    heatmap(reshape(x4,28,28)[:,28:-1:1],flip=true,color=:blues, title="2"),
    layout = @layout [a b ; c d]
)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 28.9273,175.813 280.315,175.813 280.315,31.4961 28.9273,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="31" width="192" height="145"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   189.556,33.6608 189.556,173.649
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   155.38,33.6608 155.38,173.649
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.203,33.6608 121.203,173.649
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   87.0271,33.6608 87.0271,173.649
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.8507,33.6608 52.8507,173.649
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,54.6899 31.7981,54.6899
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,80.4609 31.7981,80.4609
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,106.232 31.7981,106.232
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,132.003 31.7981,132.003
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,157.774 31.7981,157.774
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,31.4961 28.9273,31.4961
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,31.4961 220.315,175.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   189.556,31.4961 189.556,33.6608
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   155.38,31.4961 155.38,33.6608
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.203,31.4961 121.203,33.6608
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   87.0271,31.4961 87.0271,33.6608
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.8507,31.4961 52.8507,33.6608
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,54.6899 217.444,54.6899
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,80.4609 217.444,80.4609
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,106.232 217.444,106.232
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,132.003 217.444,132.003
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,157.774 217.444,157.774
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0,
# %% [markdown]
# We use `A` to hash the 4 data samples, zeroizing all the largest 5% (353) and (by default) setting the remaining entries to 1.0

# %%
h1 = buzzhash(A,x1,353)
h2 = buzzhash(A,x2,353)
h3 = buzzhash(A,x3,353)
h4 = buzzhash(A,x4,353);

# %% [markdown]
# We display the data (blue) and their hashes (green) side by side.

# %%
plot(
    heatmap(reshape(x1,28,28)[:,28:-1:1],flip=true,color=:blues, title="2"),
    heatmap(reshape(h1,28*3,28*3),color=:greens, title="hash of 2"),
    heatmap(reshape(x2,28,28)[:,28:-1:1],flip=true,color=:blues, title="7"),
    heatmap(reshape(h2,28*3,28*3),color=:greens, title="hash of 7"),
    layout = @layout [a b ; c d]
)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7700)" points="
# 28.9273,175.813 280.315,175.813 280.315,31.4961 28.9273,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="31" width="192" height="145"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   189.556,33.6608 189.556,173.649
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   155.38,33.6608 155.38,173.649
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.203,33.6608 121.203,173.649
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   87.0271,33.6608 87.0271,173.649
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.8507,33.6608 52.8507,173.649
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,54.6899 31.7981,54.6899
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,80.4609 31.7981,80.4609
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,106.232 31.7981,106.232
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,132.003 31.7981,132.003
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   217.444,157.774 31.7981,157.774
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,31.4961 28.9273,31.4961
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,31.4961 220.315,175.813
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   189.556,31.4961 189.556,33.6608
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   155.38,31.4961 155.38,33.6608
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.203,31.4961 121.203,33.6608
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   87.0271,31.4961 87.0271,33.6608
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.8507,31.4961 52.8507,33.6608
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,54.6899 217.444,54.6899
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,80.4609 217.444,80.4609
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,106.232 217.444,106.232
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,132.003 217.444,132.003
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.315,157.774 217.444,157.774
#   "/>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 189.556, 189.613)" x="189.556" y="189.613">5</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.38, 189.613)" x="155.38" y="189.613">10</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.203, 189.613)" x="121.203" y="189.613">15</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 87.0271, 189.613)" x="87.0271" y="189.613">20</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 52.8507, 189.613)" x="52.8507" y="189.613">25</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 59.1899)" x="22.9273" y="59.1899">5</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 84.9609)" x="22.9273" y="84.9609">10</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 110.732)" x="22.9273" y="110.732">15</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 136.503)" x="22.9273" y="136.503">20</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 162.274)" x="22.9273" y="162.274">25</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 124.621, 18)" x="124.621" y="18">2</text>
# </g>
# <g clip-path="url(#clip7702)">
# <image width="191" height="144" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAL8AAACQCAYAAABZELrlAAAEG0lEQVR4nO3dzUuUURiGcSd1bHTM
# THNhRUYTU5HQovaRUiCEQRkFCmGrwF27Wgj9Ae2DmiBoFYIf0EIqyrCyQJM+lL4tGRNJRZwcNLON
# G+E8w6gz86r39VuehzcOeXHgTNOrr2UwupAFCNrk9QYArxA/ZBE/ZBE/ZBE/ZBE/ZBE/ZBE/ZBE/
# ZBE/ZOV4vYGNIjY1a876u0fMWevtAXOWH8w1Z/VXDjvXQ5Ul5jNYipMfsogfsogfsogfsrjwpsjc
text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.38, 189.613)" x="155.38" y="189.613">10</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.203, 189.613)" x="121.203" y="189.613">15</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 87.0271, 189.613)" x="87.0271" y="189.613">20</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 52.8507, 189.613)" x="52.8507" y="189.613">25</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 59.1899)" x="22.9273" y="59.1899">5</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 84.9609)" x="22.9273" y="84.9609">10</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 110.732)" x="22.9273" y="110.732">15</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 136.503)" x="22.9273" y="136.503">20</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.9273, 162.274)" x="22.9273" y="162.274">25</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 124.621, 18)" x="124.621" y="18">9</text>
# </g>
# <g clip-path="url(#clip7902)">
# <image width="191" height="144" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAL8AAACQCAYAAABZELrlAAAFgklEQVR4nO3dS2wVVRzH8bn0ibXN
# bXtjwVcLBcFKNZpgVUxdlEBolNQ3iTEYbTExsjBxoSuJEo0JxpVRE6gx7jD10Zi4UCACVXnYSq1Y
# wSLEUgEpAcKjKa11icbznzDT6b0z/X0/y/PPzJy0v5zkf+fMTKqjf2jCAwTNyPUEgFwh/JBF+CGL
# 8EMW4Ycswg9ZhB+yCD9kEX7IIvyQRfghi/BDFuGHLMIPWYQfsgg/ZBF+yCL8kEX4IYvwQxbhhyzC
# D1mEH7IIP2QRfsgi/JBF+CGL8EMW4Ycswg9Z+bmeQNKMj/3tHD/YO2we0719yKx1tu83a5dG3dfy
# PM+bWVLgHG9+coF5zF3LbjBrc+sqzNp0xcoPWYQfsgg/ZBF+yErxTa7/82teN7/T6xz/ceefkc9j
# wuc/k0oFP19ZebFZe/nd+8zavPrK4BdLAFZ+yCL8kEX4IYvwQxbhhyzZX3sO7jtp1t58frtZO3Nq
# JPC1SkoLzVppeZFZe2jNLWZtxxeHneM/fX/siuf1b7WL7F90Xv1wqVkrLM4Ldb04YOWHLMIPWYQf
# sgg/ZCV+P7/fnveO9/vM2paPfzNrYZrae5urzdrKp+vM2pybywNfy/M8r2ah+7jPN9nPB3R9ecSs
# DfTZWzr6dh03az077GcV0hn3doqWVvvvkZefvfWYlR+yCD9kEX7IIvyQlfiGt7/7hFnreM9ueP1c
# XWbfkb17+Y3O8dUv3WEeU1Qc/Z/ZapSbHqk1j/FreP20v77XrB0fPBf4fE2PzjNr6Ur7mYOosfJD
# FuGHLMIPWYQfshLR8Prdxf1so31HM6z5t2XM2pp1d0Z+Pcv4uL3b/KMNPc7xncZW58kI09R6nudV
# Vl3lHM8viMeaG49ZADlA+CGL8EMW4YesRDS8v/b8ZdZ6vwv3zGpZ2n52tuUZe8ttNm1av8esfbXZ
# 3pIdFy+8tcQ57ncHPZtY+SGL8EMW4Ycswg9ZiWh4d3/9R+TnvG5umVmrW3xN4PMNHT5r1vq77Ya9
# s/0Xs

# %% [markdown]
# Of course the hashes, or ensemble codes, are not visually instructive but the main reference proves they are locality sensitive, i.e., they preserve similarity in a well-defined formal sense.
#
# Having a binary hash is computationally efficient for comparison purposes. The binary default may be overridden by letting the optional parameter, `clip`, be `false`.
